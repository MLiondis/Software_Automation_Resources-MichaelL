# %% [markdown]
# # Week 2 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import generate_data

plt.style.use('ggplot')

# %% [markdown]
# **1. Using MD syntax, create a table of the two regression algorithms we have covered so far with the following headings.**
#
# - Algorythm
# - Regression or Classification
# - Popular uses

# %% [markdown]
# | Algorithm | Regression or Classification | Popular uses |
# | - | - | - |
# | linear regression | Regression | forecasting sales, estimating real estate prices, analyzing market ROI |
# | logistic regression | Classification | fraud detection in banking, disease diagnosis, and spam detection |

# %% [markdown]
# **2. In a markdown block, outline why more than 3 degrees of polynomial expression are not recommended in Machine Learning.**

# %% [markdown]
# More than 3 degrees of polynomial expression are not recommended in machine learning due to the possibility of overfitting the model. Once more than 3 degrees are implemented, the model fits too closely to the training data, and will cause overfitting to occur.

# %% [markdown]
# **3. Modify the code block below to label the two categories, apply a colour to each category, enable the legend, add a title "Logistic Data," and label the X & Y Axis with "Feature" and "Target."**
#
# | Category | Label |
# | --- | --- |
# | 0 | Australia |
# | 1 | New Zealand |

# %%
# Linear Regression For Classification
Aus = generate_data(20, 50, 0, 0, 300, 0.8)
NZ = generate_data(0, 30, 1, 1, 300, 0.8)
plt.scatter(Aus[0], Aus[1], c='blue')
plt.scatter(NZ[0], NZ[1], c='green')
plt.legend()
plt.title("Logistic Data")
plt.xlabel("Feature")
plt.ylabel("Target")
plt.show()
# Out:
# /tmp/ipykernel_2373/794522928.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **4. In a markdown block, outline why Linear Regression is not a good machine learning model for classification.**

# %% [markdown]
# Linear regression can predict values outside of the range from 0-1, which makes no sense for classification targets such as "spam" or "not spam"

# %% [markdown]
# __5. In a markdown block, outline the machine learning Logistic Regression algorithm.__

# %% [markdown]
# A supervised machine learning algorithm that is used primarily for classification tasks, particularly binary classification tasks. It works by using a linear equation, which is transformed by a special sigmoid function to output a probability value between 0 and 1 to determine how not probable it is to be the other.

# %% [markdown]
# **6. Using the [OOP Logistic Regression](4.OOP_Logistic_Regression.ipynb) as an example, design, fit and evaluate an [Iris classification OOP implementation](6.OOP_Iris_Logistic_Regression.ipynb).**

# %% [markdown]
# __7. After completing Logistic Regression for the Iris data set (Q6), justify why you selected the features you did for your model.__
